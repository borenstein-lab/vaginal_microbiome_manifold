# %%
from os.path import join
import pandas as pd
import xlsxwriter
import openpyxl
import os
import numpy as np
import itertools
import itertools as it
from pandas import Series, ExcelWriter
import csv
from skbio.stats.composition import clr
import plotly.express as px
import matplotlib.pyplot as plt

# %% [markdown]
# #### Variables

# %%
top_path = 'C:/Users/morts/Documents/TAU/Manifold_Project/Data/SPECIFIC_PAPERS/'
# top_path = 'C:/Users/morts/Documents/TAU/RF_Project/Data/'

db_path1 = top_path + 'Ravel_et_al.2013/Hiseq_sequencing/DADA2_results/'
db_path2 = top_path + 'Ravel_et_al.2013/454_Sequencing/DADA2_results/DADA_output_files/'
db_path3 = top_path + 'Carter_et_al.2022/DADA2_results/'
db_path4 = top_path + 'Ravel_et_al.2011/DADA2_results/'
db_path5 = top_path + 'Serrano_et_al.2019/noDuplicatedID/DADA2_results/'
db_path6 = top_path + 'Srinivasan2012/DADA2_results/'
# db_path3 = top_path + 'Ceccarani2019/DADA2_results/'


asv_abun_file_name = 'abundance_ASV.csv'
taxa_file_name = 'taxa_ASV.csv'

speciate_filename1 = 'Ravel2013_Hiseq_2step_single_V3V4_MC_order7.txt'
speciate_filename2 = 'Ravel2013_V1V3_454_all_MC_order7_rev.txt'
speciate_filename3 = 'Carter2022_V3V4_MC_order7.txt'
speciate_filename4 = 'Ravel2011_V1V3_MC_order7.txt'
speciate_filename5 = 'Serrano2019_MC_order7.txt'
speciate_filename6 = 'Srinivasan2012_V3V4_MC_order7.txt'
# speciate_filename3 = 'Ceccarani2019_V3V4_MC_order7.txt'

taxa_names_lst = ['k','p','c','o','f','g','s']
names_lst = ['Lactobacillus', 'Gardnerella', 'Prevotella', 'Atopobium', 'Shuttleworthia', 'Sneathia', 'BVAB', 'Unknown']
date = '16052023'

# %% [markdown]
# #### Functions

# %%
def order_tax(df):
    new_df = df.copy()
    new_df = df.fillna(0)
    new_df.columns = taxa_names_lst
    new_df['cond_spec'] = np.nan
    
    return new_df

# %%
def get_cond(row):
    if type(row['s']) == str:
        row['cond_spec'] = row['g'] + '_' + row['s']
    
    else:
        for i in range(len(taxa_names_lst)):
            curr_level = taxa_names_lst[i]
            if row[curr_level] == 0:
                if curr_level == 'k':
                    row['cond_spec'] = np.nan
                else:
                    upper_level = taxa_names_lst[i - 1]
                    row['cond_spec'] = upper_level + '_' + row[upper_level]
                break
    
    return row

# %%
def order_speciate(df):
    df.columns = ['ASV', 'speciate_spec', 'posterior_probability', 'decisions_num']
    df.drop(['posterior_probability', 'decisions_num'], axis = 1, inplace = True)
    df.set_index('ASV', inplace = True)
    
    return df

# %%
def add_final_name(row):
    if any(name in row['speciate_spec'] for name in names_lst) or 'BVAB' in row['speciate_spec']:
        return row['speciate_spec']
    else:
        if row['g'] is not 'Unknown' and '00' not in row['g']:
            return 'g_' + row['g']
        elif row['f'] != 0:
            return 'f_' + row['f']
        elif row['s'] == 0: 
            return row['cond_spec']
        else:
            return 'Unknown'

# %%
def get_new_name(name):
    if name.split('_')[0] == 'f':
        return name
    elif 'Cluster' in name:
        return name
    elif len(name.split('_')[0]) == 1 and name.split('_')[0] != 'f':
        return '_'.join(name.split('_')[:2])
    elif any(map(str.isdigit, name.split('_')[1])):
        return '_'.join([name.split('_')[i] for i in [0, 2]])
    else: 
        return '_'.join(name.split('_')[-2:])

# %%
def get_spec_df(path, spec_path):
    ## DADA tax df
    tax_df_orig = pd.read_csv(path + taxa_file_name, index_col = 0)
    print('Tax_df row num: ' + str(tax_df_orig.shape[0]))
    
    tax_df = order_tax(tax_df_orig)
    tax_df = tax_df.apply(lambda row: get_cond(row), axis = 1)
    tax_df['g'] = tax_df['g'].replace({0: 'Unknown'})
    
    ## Speciate df
    speciate_df = pd.read_csv(path + spec_path, sep = '\t', header = None)
    print('Speciateit row num: ' + str(speciate_df.shape[0]))
    speciate_df = order_speciate(speciate_df)
    
    ## Merge both dfs
    merged_tax_df = tax_df.join(speciate_df)
    
    ## Create final name column
    merged_tax_df['final_name'] = merged_tax_df.apply(add_final_name, axis = 1)
    
    ## Replace long names
    long_names_lst = [name for name in merged_tax_df.final_name.unique() if type(name) == str and name.count('_') > 1]
    print('Long names lst: ')
    print(*long_names_lst, sep = '\n')
    
    new_names = []
    for name in long_names_lst:
        new_name = get_new_name(name)
        new_names.append(new_name)
        
    replacers = dict(zip(long_names_lst, new_names))
    replacers.update({'Lactobacillus_ultunensis': 'Lactobacillus_crispatus'})

    merged_tax_df['final_name'] = merged_tax_df['final_name'].replace(replacers)
    merged_tax_df = merged_tax_df.loc[(merged_tax_df['p'] != 0)]
    print('Merged tax df after removal of k_ ASVs: ' + str(merged_tax_df.shape[0]))
    
    long_names_lst = [name for name in merged_tax_df.final_name.unique() if name.count('_') > 1]
    print((long_names_lst))
    
    return merged_tax_df

# %%
def get_spec_reads_table(path, merged_tax_df):
    abun_df = pd.read_csv(path + asv_abun_file_name, index_col = 0)
    print('Orig reads table columns: ' + str(abun_df.shape[1]))
    
    filt_abun_df = abun_df[merged_tax_df.index]
    abun_df_t = filt_abun_df.T
    spec_abun_df = pd.merge(merged_tax_df[['final_name']], abun_df_t, left_index = True, right_index = True)

    spec_abun_df.reset_index(drop = True, inplace = True)
    spec_abun_df.set_index('final_name', inplace = True)
    spec_abun_df.index.name = None
    spec_abun_df = spec_abun_df.T
    print('Final reads table columns: ' + str(spec_abun_df.shape[1]))
        
    return spec_abun_df

# %%
def get_filtered(df):
    filt_df = df.loc[df.sum(axis = 1) >= 1000]
    filt_df02 = filt_df.loc[:, filt_df.sum(axis = 0) >= 100]
    filt_df03 = filt_df02.drop(filt_df02.loc[filt_df02.sum(axis = 1) == 0].index, inplace = False)
    
    print('Shape after filter- rows: ' + str(filt_df03.shape[0]) + ', columns: ' + str(filt_df03.shape[1]))

    return filt_df03

# %%
def sum_spec(df):
    sum_spec_df = df.groupby(df.columns, axis = 1).sum()
    print('Sum of species columns: ' + str(sum_spec_df.shape[1]))
    
    return sum_spec_df

# %%
def get_valencia_input(df):   
    valencia_df = df.copy()
    valencia_df.reset_index(inplace = True)
    valencia_df = valencia_df.rename(columns = {'index':'sampleID'})
    read_count_values = valencia_df.sum(axis = 1)
    valencia_df.insert(loc = 1, column = 'read_count', value = read_count_values)
    
    return valencia_df

# %%
def save_and_cmd_valencia(path, df):
    valencia_file_name = 'valencia_df_' + date 
    df.to_csv(path + valencia_file_name + '.csv', index = False)
    
    in_file = path + valencia_file_name + '.csv'
    out_file = path + valencia_file_name + '_res'
    cmd = 'py C:/Users/morts/Documents/TAU/Python_Scripts/Manifold_Project/Valencia/Valencia.py -ref C:/Users/morts/Documents/TAU/Taxonomy/CST_centroids_19042023.csv -i ' + in_file + ' -o ' + out_file
    print('*** cmd for VALENCIA ***')
    print(cmd)
    
    return

# %%
def all_func(name, path, spec_path):
    ## Table with ASV and taxa final
    merged_tax_df = get_spec_df(path, spec_path)
    
    ## Reads table with taxa names (after sum)
    spec_abun_df = get_spec_reads_table(path, merged_tax_df)
    
    ## Filtering
    filt_df = get_filtered(spec_abun_df)
    sum_spec_df = sum_spec(filt_df)
    
    ## VALENCIA input
    input_valencia = get_valencia_input(sum_spec_df)
    save_and_cmd_valencia(path, input_valencia)
    
    print('****  ****  ****')
    
    return merged_tax_df

# %% [markdown]
# #### Run

# %%
db_lst = [db_path1, db_path2, db_path3, db_path4, db_path5, db_path6]
speciate_lst = [speciate_filename1, speciate_filename2, speciate_filename3, speciate_filename4, speciate_filenam5, speciate_filename6]

# %%
for i, path in enumerate(db_lst):
    df = all_func('test', db_lst[i], speciate_lst[i])
    print('***')
# Out:
# Tax_df row num: 22633
# Speciateit row num: 22633
# Long names lst:
# Atopobium_sp_Atopobium_parvulum_Atopobium_rimae_Atopobium_vaginae
# g_Corynebacterium_1
# Lactobacillus_vaginalis_Lactobacillus_reuteri
# g_Rikenellaceae_RC9_gut_group
# g_Clostridium_sensu_stricto_1
# f_Bacteroidales_S24-7_group
# g_Ruminococcaceae_UCG-014
# f_Family_XI
# Lactobacillus_acidophilus_Lactobacillus_sp_Lactobacillus_taiwanensis_Lactobacillus_johnsonii
# f_Family_XIII
# g_Prevotella_7
# Lactobacillus_kitasatonis_Lactobacillus_gallinarum_Lactobacillus_crispatus
# g_Tyzzerella_4
# g_Ruminococcus_2
# g_Christensenellaceae_R-7_group
# f_Clostridiaceae_1
# g_Coprococcus_2
# g_Ruminiclostridium_5
# g_Ruminococcus_1
# g_Prevotella_6
# g_Ruminiclostridium_6
# g_Ruminococcaceae_NK4A214_group
# p_SR1_(Absconditabacteria)
# g_Prevotella_9
# f_Clostridiales_vadinBB60_group
# o_Mollicutes_RF9
# g_Treponema_2
# g_Ruminococcaceae_UCG-013
# g_Lachnoclostridium_5
# Lactobacillus_murinus_Lactobacillus_apodemi
# g_Family_XIII_AD3011_group
# g_Ruminococcaceae_UCG-010
# f_Clostridiaceae_3
# g_Candidatus_Saccharimonas
# g_Ruminiclostridium_1
# g_Blvii28_wastewater-sludge_group
# g_Coprococcus_1
# Lactobacillus_hamsteri_Lactobacillus_amylolyticus
# g_Lachnospiraceae_UCG-010
# g_Ruminiclostridium_9
# g_Selenomonas_3
# g_Butyrivibrio_2
# g_Candidatus_Stoquefichus
# Prevotella_genomosp_Prevotella_fusca_Prevotella_loescheii_Prevotella_conceptionensis
# g_Candidatus_Soleaferrea
# g_Ruminococcaceae_UCG-011
# o_Alphaproteobacteria_Incertae_Sedis
# g_Lachnospiraceae_NK3A20_group
# g_Defluviitaleaceae_UCG-011
# g_Candidatus_Captivus
# f_Bacteroidales_BS11_gut_group
# f_Clostridiaceae_2
# f_DA101_soil_group
# f_Aphagea_fa
# g_Candidatus_Protochlamydia
# g_Coprococcus_3
# Lactobacillus_fructivorans_Lactobacillus_acetotolerans
# c_Subgroup_6
# g_Tyzzerella_3
# g_Candidatus_Arthromitus
# g_dgA-11_gut_group
# Merged tax df after removal of k_ ASVs: 17495
# ['f_Bacteroidales_S24-7_group', 'f_Family_XI', 'f_Family_XIII', 'f_Clostridiaceae_1', 'f_Clostridiales_vadinBB60_group', 'f_Clostridiaceae_3', 'f_Bacteroidales_BS11_gut_group', 'f_Clostridiaceae_2', 'f_DA101_soil_group', 'f_Aphagea_fa']
# Orig reads table columns: 22633
# Final reads table columns: 17495
# Shape after filter- rows: 3412, columns: 8638
# Sum of species columns: 278
# *** cmd for VALENCIA ***
# py C:/Users/morts/Documents/TAU/Python_Scripts/Manifold_Project/Valencia/Valencia.py -ref C:/Users/morts/Documents/TAU/Taxonomy/CST_centroids_19042023.csv -i C:/Users/morts/Documents/TAU/Manifold_Project/Data/SPECIFIC_PAPERS/Ravel_et_al.2013/Hiseq_sequencing/DADA2_results/valencia_df_16052023.csv -o C:/Users/morts/Documents/TAU/Manifold_Project/Data/SPECIFIC_PAPERS/Ravel_et_al.2013/Hiseq_sequencing/DADA2_results/valencia_df_16052023_res
# ****  ****  ****
# ***
# Tax_df row num: 6676
# Speciateit row num: 6676
# Long names lst:
# Atopobium_sp_Atopobium_parvulum_Atopobium_rimae_Atopobium_vaginae
# Lactobacillus_Cluster_1
# Lactobacillus_murinus_Lactobacillus_animalis
# Merged tax df after removal of k_ ASVs: 6545
# ['Lactobacillus_Cluster_1']
# Orig reads table columns: 6676
# Final reads table columns: 6545
# Shape after filter- rows: 1573, columns: 1516
# Sum of species columns: 82
# *** cmd for VALENCIA ***
# py C:/Users/morts/Documents/TAU/Python_Scripts/Manifold_Project/Valencia/Valencia.py -ref C:/Users/morts/Documents/TAU/Taxonomy/CST_centroids_19042023.csv -i C:/Users/morts/Documents/TAU/Manifold_Project/Data/SPECIFIC_PAPERS/Ravel_et_al.2013/454_Sequencing/DADA2_results/DADA_output_files/valencia_df_16052023.csv -o C:/Users/morts/Documents/TAU/Manifold_Project/Data/SPECIFIC_PAPERS/Ravel_et_al.2013/454_Sequencing/DADA2_results/DADA_output_files/valencia_df_16052023_res
# ****  ****  ****
# ***
# Tax_df row num: 3598
# Speciateit row num: 3598
# Long names lst:
# Atopobium_sp_Atopobium_parvulum_Atopobium_rimae_Atopobium_vaginae
# Lactobacillus_vaginalis_Lactobacillus_reuteri
# Lactobacillus_murinus_Lactobacillus_apodemi
# Lactobacillus_acidophilus_Lactobacillus_sp_Lactobacillus_taiwanensis_Lactobacillus_johnsonii
# g_Rikenellaceae_RC9_gut_group
# f_Bacteroidales_S24-7_group
# Lactobacillus_kitasatonis_Lactobacillus_gallinarum_Lactobacillus_crispatus
# g_Corynebacterium_1
# g_Prevotella_7
# g_Candidatus_Captivus
# g_Prevotella_9
# Lactobacillus_zeae_Lactobacillus_casei_Lactobacillus_paracasei
# g_Ruminococcaceae_UCG-014
# g_Christensenellaceae_R-7_group
# g_Candidatus_Saccharimonas
# g_Clostridium_sensu_stricto_1
# f_Family_XIII
# g_Ruminiclostridium_6
# g_Ruminococcus_2
# g_Coprococcus_2
# g_Tyzzerella_4
# g_Ruminococcaceae_NK4A214_group
# g_Ruminococcus_1
# g_Ruminococcaceae_UCG-010
# g_Treponema_2
# g_Butyrivibrio_2
# f_Clostridiaceae_1
# g_Lachnospiraceae_UCG-010
# g_Prevotella_6
# g_Family_XIII_AD3011_group
# g_Selenomonas_4
# f_Clostridiales_vadinBB60_group
# f_Family_XI
# g_Clostridium_sensu_stricto_10
# g_Ruminococcaceae_UCG-013
# p_TM6_(Dependentiae)
# c_Subgroup_6
# f_NS11-12_marine_group
# o_Mollicutes_RF9
# g_Ruminiclostridium_9
# g_hgcI_clade
# g_Ruminiclostridium_5
# f_Unknown_Family
# Merged tax df after removal of k_ ASVs: 3544
# ['f_Bacteroidales_S24-7_group', 'f_Family_XIII', 'f_Clostridiaceae_1', 'f_Clostridiales_vadinBB60_group', 'f_Family_XI', 'f_NS11-12_marine_group', 'f_Unknown_Family']
# Orig reads table columns: 3598
# Final reads table columns: 3544
# Shape after filter- rows: 706, columns: 1576
# Sum of species columns: 137
# *** cmd for VALENCIA ***
# py C:/Users/morts/Documents/TAU/Python_Scripts/Manifold_Project/Valencia/Valencia.py -ref C:/Users/morts/Documents/TAU/Taxonomy/CST_centroids_19042023.csv -i C:/Users/morts/Documents/TAU/Manifold_Project/Data/SPECIFIC_PAPERS/Carter_et_al.2022/DADA2_results/valencia_df_16052023.csv -o C:/Users/morts/Documents/TAU/Manifold_Project/Data/SPECIFIC_PAPERS/Carter_et_al.2022/DADA2_results/valencia_df_16052023_res
# ****  ****  ****
# ***
# Tax_df row num: 4851
# Speciateit row num: 4851
# Long names lst:
# Lactobacillus_Cluster_1
# Atopobium_sp_Atopobium_parvulum_Atopobium_rimae_Atopobium_vaginae
# Lactobacillus_gallinarum_Lactobacillus_helveticus
# g_Prevotella_7
# Lactobacillus_salivarius_Lactobacillus_phage
# Merged tax df after removal of k_ ASVs: 4840
# ['Lactobacillus_Cluster_1']
# Orig reads table columns: 4851
# Final reads table columns: 4840
# Shape after filter- rows: 385, columns: 875
# Sum of species columns: 54
# *** cmd for VALENCIA ***
# py C:/Users/morts/Documents/TAU/Python_Scripts/Manifold_Project/Valencia/Valencia.py -ref C:/Users/morts/Documents/TAU/Taxonomy/CST_centroids_19042023.csv -i C:/Users/morts/Documents/TAU/Manifold_Project/Data/SPECIFIC_PAPERS/Ravel_et_al.2011/DADA2_results/valencia_df_16052023.csv -o C:/Users/morts/Documents/TAU/Manifold_Project/Data/SPECIFIC_PAPERS/Ravel_et_al.2011/DADA2_results/valencia_df_16052023_res
# ****  ****  ****
# ***

# %% [markdown]
# #### Check results

# %%
df = all_func('test', db_path5, speciate_filename5)
# Out:
# Tax_df row num: 37719
# Speciateit row num: 37719
# Long names lst:
# Atopobium_sp_Atopobium_parvulum_Atopobium_rimae_Atopobium_vaginae
# Lactobacillus_Cluster_1
# Lactobacillus_gallinarum_Lactobacillus_helveticus
# Lactobacillus_zeae_Lactobacillus_casei_Lactobacillus_paracasei
# Lactobacillus_salivarius_Lactobacillus_phage
# g_Prevotella_7
# Lactobacillus_murinus_Lactobacillus_animalis
# Prevotella_loescheii_Prevotella_genomosp_Prevotella_conceptionensis
# Lactobacillus_parabuchneri_Lactobacillus_rapi
# Merged tax df after removal of k_ ASVs: 37240
# ['Lactobacillus_Cluster_1']
# Orig reads table columns: 37719
# Final reads table columns: 37240
# Shape after filter- rows: 3879, columns: 7835
# Sum of species columns: 278
# *** cmd for VALENCIA ***
# py C:/Users/morts/Documents/TAU/Python_Scripts/Manifold_Project/Valencia/Valencia.py -ref C:/Users/morts/Documents/TAU/Taxonomy/CST_centroids_19042023.csv -i C:/Users/morts/Documents/TAU/Manifold_Project/Data/SPECIFIC_PAPERS/Serrano_et_al.2019/noDuplicatedID/DADA2_results/valencia_df_16052023.csv -o C:/Users/morts/Documents/TAU/Manifold_Project/Data/SPECIFIC_PAPERS/Serrano_et_al.2019/noDuplicatedID/DADA2_results/valencia_df_16052023_res
# ****  ****  ****

# %%
df[df['cond_spec'].str.contains('00')]
# Out:
#                  k                 p               c  \
# ASV82     Bacteria  Actinobacteriota  Coriobacteriia
# ASV277    Bacteria  Actinobacteriota  Coriobacteriia
# ASV473    Bacteria  Actinobacteriota  Coriobacteriia
# ASV867    Bacteria  Actinobacteriota  Coriobacteriia
# ASV1082   Bacteria  Actinobacteriota  Coriobacteriia
# ...            ...               ...             ...
# ASV36941  Bacteria  Actinobacteriota  Coriobacteriia
# ASV37484  Bacteria  Actinobacteriota  Coriobacteriia
# ASV37515  Bacteria        Firmicutes      Clostridia
# ASV37531  Bacteria  Actinobacteriota  Coriobacteriia
# ASV37597  Bacteria        Firmicutes      Clostridia
#
#                                             o                 f  \
# ASV82                        Coriobacteriales   Eggerthellaceae
# ASV277                       Coriobacteriales   Eggerthellaceae
# ASV473                       Coriobacteriales   Eggerthellaceae
# ASV867                       Coriobacteriales   Eggerthellaceae
# ASV1082                      Coriobacteriales   Eggerthellaceae
# ...                                       ...               ...
# ASV36941                     Coriobacteriales   Eggerthellaceae
# ASV37484                     Coriobacteriales   Eggerthellaceae
# ASV37515                      Oscillospirales  Oscillospiraceae
# ASV37531                     Coriobacteriales   Eggerthellaceae
# ASV37597  Peptostreptococcales-Tissierellales  Anaerovoracaceae
#
#                             g  s              cond_spec  \
# ASV82                DNF00809  0             g_DNF00809
# ASV277               DNF00809  0             g_DNF00809
# ASV473               DNF00809  0             g_DNF00809
# ASV867               DNF00809  0             g_DNF00809
# ASV1082              DNF00809  0             g_DNF00809
# ...                       ... ..                    ...
# ASV36941             DNF00809  0             g_DNF00809
# ASV37484             DNF00809  0             g_DNF00809
# ASV37515              UCG-002  0              g_UCG-002
# ASV37531             DNF00809  0             g_DNF00809
# ASV37597  Family XIII UCG-001  0  g_Family XIII UCG-001
#
#                                      speciate_spec          final_name
# ASV82     Gordonibacter_sp_Gordonibacter_pamelaeae   f_Eggerthellaceae
# ASV277    Gordonibacter_sp_Gordonibacter_pamelaeae   f_Eggerthellaceae
# ASV473                       Parvibacter_caecicola   f_Eggerthellaceae
# ASV867    Gordonibacter_sp_Gordonibacter_pamelaeae   f_Eggerthellaceae
# ASV1082   Gordonibacter_sp_Gordonibacter_pamelaeae   f_Eggerthellaceae
# ...                                            ...                 ...
# ASV36941                        Cellulosibacter_sp   f_Eggerthellaceae
# ASV37484                        Limnochorda_pilosa   f_Eggerthellaceae
# ASV37515                          Oscillibacter_sp  f_Oscillospiraceae
# ASV37531                  Gorbachella_massiliensis   f_Eggerthellaceae
# ASV37597                            Eubacterium_sp  f_Anaerovoracaceae
#
# [375 rows x 10 columns]

# %%
df[df['speciate_spec'].str.contains('BVAB')]
# Out:
#                  k           p              c                               o  \
# ASV4      Bacteria  Firmicutes     Clostridia                  Lachnospirales
# ASV6      Bacteria  Firmicutes     Clostridia                  Lachnospirales
# ASV24     Bacteria  Firmicutes     Clostridia                  Lachnospirales
# ASV34     Bacteria  Firmicutes     Clostridia                  Lachnospirales
# ASV39     Bacteria  Firmicutes     Clostridia                  Lachnospirales
# ...            ...         ...            ...                             ...
# ASV37591  Bacteria  Firmicutes     Clostridia                  Lachnospirales
# ASV37598  Bacteria  Firmicutes     Clostridia                  Lachnospirales
# ASV37630  Bacteria  Firmicutes     Clostridia                  Lachnospirales
# ASV37691  Bacteria  Firmicutes  Negativicutes  Veillonellales-Selenomonadales
# ASV37712  Bacteria  Firmicutes     Clostridia                  Lachnospirales
#
#                         f               g  s          cond_spec speciate_spec  \
# ASV4      Lachnospiraceae  Shuttleworthia  0   g_Shuttleworthia         BVAB1
# ASV6      Lachnospiraceae  Shuttleworthia  0   g_Shuttleworthia         BVAB1
# ASV24     Lachnospiraceae  Shuttleworthia  0   g_Shuttleworthia         BVAB1
# ASV34     Lachnospiraceae  Shuttleworthia  0   g_Shuttleworthia         BVAB1
# ASV39     Lachnospiraceae  Shuttleworthia  0   g_Shuttleworthia         BVAB1
# ...                   ...             ... ..                ...           ...
# ASV37591  Lachnospiraceae  Shuttleworthia  0   g_Shuttleworthia         BVAB1
# ASV37598  Lachnospiraceae  Shuttleworthia  0   g_Shuttleworthia         BVAB1
# ASV37630  Lachnospiraceae  Shuttleworthia  0   g_Shuttleworthia         BVAB1
# ASV37691  Veillonellaceae         Unknown  0  f_Veillonellaceae         BVAB1
# ASV37712  Lachnospiraceae  Shuttleworthia  0   g_Shuttleworthia         BVAB1
#
#          final_name
# ASV4          BVAB1
# ASV6          BVAB1
# ASV24         BVAB1
# ASV34         BVAB1
# ASV39         BVAB1
# ...             ...
# ASV37591      BVAB1
# ASV37598      BVAB1
# ASV37630      BVAB1
# ASV37691      BVAB1
# ASV37712      BVAB1
#
# [1418 rows x 10 columns]

# %%
test1 = all_func('9', db_path1, speciate_filename1)

# %%
test2 = get_spec_df(db_path1, speciate_filename1)
# Out:
# Tax_df row num: 6676
# Speciateit row num: 6676
# Long names lst:
# g_Prevotella_7
# Lactobacillus_Cluster_1
# Lactobacillus_murinus_Lactobacillus_animalis
# Merged tax df after removal of k_ ASVs: 6545
# ['Lactobacillus_Cluster_1']

# %%
test2.loc[test2['final_name'] == 'g_Gardnerella']
# Out:
#                 k                 p               c                  o  \
# ASV1179  Bacteria  Actinobacteriota  Actinobacteria  Bifidobacteriales
# ASV1526  Bacteria  Actinobacteriota  Actinobacteria  Bifidobacteriales
# ASV1575  Bacteria  Actinobacteriota  Actinobacteria  Bifidobacteriales
# ASV1623  Bacteria  Actinobacteriota  Actinobacteria  Bifidobacteriales
# ASV1734  Bacteria  Actinobacteriota  Actinobacteria  Bifidobacteriales
# ...           ...               ...             ...                ...
# ASV6486  Bacteria  Actinobacteriota  Actinobacteria  Bifidobacteriales
# ASV6500  Bacteria  Actinobacteriota  Actinobacteria  Bifidobacteriales
# ASV6537  Bacteria  Actinobacteriota  Actinobacteria  Bifidobacteriales
# ASV6637  Bacteria  Actinobacteriota  Actinobacteria  Bifidobacteriales
# ASV6669  Bacteria  Actinobacteriota  Actinobacteria  Bifidobacteriales
#
#                           f            g  s      cond_spec  \
# ASV1179  Bifidobacteriaceae  Gardnerella  0  g_Gardnerella
# ASV1526  Bifidobacteriaceae  Gardnerella  0  g_Gardnerella
# ASV1575  Bifidobacteriaceae  Gardnerella  0  g_Gardnerella
# ASV1623  Bifidobacteriaceae  Gardnerella  0  g_Gardnerella
# ASV1734  Bifidobacteriaceae  Gardnerella  0  g_Gardnerella
# ...                     ...          ... ..            ...
# ASV6486  Bifidobacteriaceae  Gardnerella  0  g_Gardnerella
# ASV6500  Bifidobacteriaceae  Gardnerella  0  g_Gardnerella
# ASV6537  Bifidobacteriaceae  Gardnerella  0  g_Gardnerella
# ASV6637  Bifidobacteriaceae  Gardnerella  0  g_Gardnerella
# ASV6669  Bifidobacteriaceae  Gardnerella  0  g_Gardnerella
#
#                            speciate_spec     final_name
# ASV1179          Pasteuria_goettingianae  g_Gardnerella
# ASV1526            Thermicanus_aegyptius  g_Gardnerella
# ASV1575          Pasteuria_goettingianae  g_Gardnerella
# ASV1623          Pasteuria_goettingianae  g_Gardnerella
# ASV1734          Pasteuria_goettingianae  g_Gardnerella
# ...                                  ...            ...
# ASV6486          Pasteuria_goettingianae  g_Gardnerella
# ASV6500  Salinivirga_cyanobacteriivorans  g_Gardnerella
# ASV6537          Pasteuria_goettingianae  g_Gardnerella
# ASV6637            Segniliparus_rotundus  g_Gardnerella
# ASV6669          Pasteuria_goettingianae  g_Gardnerella
#
# [117 rows x 10 columns]

# %%
test2
# Out:
#                 k                 p               c                  o  \
# ASV1     Bacteria        Firmicutes         Bacilli    Lactobacillales
# ASV2     Bacteria        Firmicutes         Bacilli    Lactobacillales
# ASV3     Bacteria  Actinobacteriota  Actinobacteria  Bifidobacteriales
# ASV4     Bacteria        Firmicutes         Bacilli    Lactobacillales
# ASV5     Bacteria  Actinobacteriota  Actinobacteria  Bifidobacteriales
# ...           ...               ...             ...                ...
# ASV6671  Bacteria      Bacteroidota     Bacteroidia      Bacteroidales
# ASV6672  Bacteria        Firmicutes      Clostridia     Lachnospirales
# ASV6673  Bacteria  Actinobacteriota  Actinobacteria  Corynebacteriales
# ASV6674  Bacteria  Actinobacteriota  Actinobacteria    Actinomycetales
# ASV6675  Bacteria  Actinobacteriota  Actinobacteria    Actinomycetales
#
#                           f                g          s  \
# ASV1       Lactobacillaceae    Lactobacillus      iners
# ASV2       Lactobacillaceae    Lactobacillus      iners
# ASV3     Bifidobacteriaceae      Gardnerella  vaginalis
# ASV4       Lactobacillaceae    Lactobacillus      iners
# ASV5     Bifidobacteriaceae      Gardnerella  vaginalis
# ...                     ...              ...        ...
# ASV6671      Bacteroidaceae      Bacteroides          0
# ASV6672     Lachnospiraceae          Blautia          0
# ASV6673  Corynebacteriaceae  Corynebacterium          0
# ASV6674    Actinomycetaceae       Mobiluncus          0
# ASV6675    Actinomycetaceae       Mobiluncus          0
#
#                      cond_spec  \
# ASV1       Lactobacillus_iners
# ASV2       Lactobacillus_iners
# ASV3     Gardnerella_vaginalis
# ASV4       Lactobacillus_iners
# ASV5     Gardnerella_vaginalis
# ...                        ...
# ASV6671          g_Bacteroides
# ASV6672              g_Blautia
# ASV6673      g_Corynebacterium
# ASV6674           g_Mobiluncus
# ASV6675           g_Mobiluncus
#
#                                              speciate_spec  \
# ASV1                                   Lactobacillus_iners
# ASV2                                   Lactobacillus_iners
# ASV3                                 Gardnerella_vaginalis
# ASV4                                   Lactobacillus_iners
# ASV5                                 Gardnerella_vaginalis
# ...                                                    ...
# ASV6671                Bacteroides_sp_Bacteroides_vulgatus
# ASV6672  Blautia_producta_Blautia_hansenii_Blautia_sp_B...
# ASV6673                         Corynebacterium_genitalium
# ASV6674                                Mobiluncus_curtisii
# ASV6675                                Mobiluncus_curtisii
#
#                     final_name
# ASV1       Lactobacillus_iners
# ASV2       Lactobacillus_iners
# ASV3     Gardnerella_vaginalis
# ASV4       Lactobacillus_iners
# ASV5     Gardnerella_vaginalis
# ...                        ...
# ASV6671          g_Bacteroides
# ASV6672              g_Blautia
# ASV6673      g_Corynebacterium
# ASV6674           g_Mobiluncus
# ASV6675           g_Mobiluncus
#
# [6545 rows x 10 columns]

# %%
spec = 'Eggerthe'
'f_Eggerthellaceae'
[col for col in df.columns if spec in col]
# any(test.apply(lambda row: row.astype(str).str.contains(spec).any(), axis=1))
# test[test['cond_spec'].str.contains(spec)]
# Out:
# []
