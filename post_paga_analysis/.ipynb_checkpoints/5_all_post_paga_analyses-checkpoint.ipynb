# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from skbio.diversity import alpha_diversity, beta_diversity
import functools
# from skbio.stats.ordination import pcoa, pcoa_biplotb
import random
from os.path import join
import pandas as pd
import xlsxwriter
import openpyxl
import os
import numpy as np
from pandas import Series, ExcelWriter
import scipy.io as sio
import scipy
import plotly.graph_objects as go
import plotly.io as pio
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import scanpy as sc 
from anndata import AnnData
import warnings
warnings.filterwarnings('ignore')
import importlib

# %%
import sys  
sys.path.insert(0, '../my_packages')
import dimen_reduc
import meta_ord
import paga_res
import sliding_window
import statistic
from roc_ps import get_shuffled_df, get_roc, all_func
# importlib.reload(dimen_reduc)
# importlib.reload(meta_ord)
# importlib.reload(paga_res)
# importlib.reload(sliding_window)
# importlib.reload(statistic)

# %% [markdown]
# ####  Variables

# %%
file_path = 'C:/Users/morts/Documents/TAU/Manifold_Project/Data/Serrano_Ravel13_Ravel11_Carter22/ps_res/'

file_name = file_path + 'ps_res_PCA_umap_02072023.xlsx'
nn_file_name = file_path + 'nn_res_PCA_umap_02072023.xlsx'

sheet_abun = 'abundance'
sheet_meta = 'meta'
sheet_umap = 'umap'
sheet_pcoa = 'pcoa'

# %%
# 0. Load data
## Pseudotime validation
# 1. ROC BV indicators
# 2. Menstruation delta
# 3. Metabolites
## Longitudinal only
# 4. BV medications
# 5. ROC BV from first days ps prediction
# 6. Bacterial abundance in arms

# %% [markdown]
# #### 0. Load data

# %%
meta = pd.read_excel(file_name, sheet_name = sheet_meta, index_col = 0)
nn_meta = pd.read_excel(nn_file_name, sheet_name = sheet_meta, index_col = 0)
display(meta.shape)
display(nn_meta.shape)
# Out:
# (8026, 35)
# (515, 37)

# %% [markdown]
# #### 1. ROC BV indicators

# %%
def order_meta(func_meta, nn):
    if nn:
        roc_meta = func_meta.copy()
    else: 
        roc_meta = func_meta[func_meta['root'] == 'reg']
    
    roc_meta['nugent_bin'] = (np.select([roc_meta['nugent'] >= 7, roc_meta['nugent'].isnull(), roc_meta['nugent'] < 7], [1, np.nan, 0]))                  
    roc_meta['ph_bin'] = (np.select([roc_meta['ph'] >= 5.5, roc_meta['ph'].isnull(), roc_meta['ph'] < 5.5], [1, np.nan, 0]))
    meta_amsel = roc_meta[roc_meta['db'].isin(['carter', 'temp_pyro', 'srin'])]
    meta_amsel['BV_amsel_bin'] = np.where((meta_amsel['BV_status'] == 'ABV') | (meta_amsel['BV_status'] == 'SBV'), 1, 0)
    
    return roc_meta, meta_amsel

def view_distributions(meta, cols =  ['nugent_bin', 'ph_bin', 'BV_amsel_bin', 'whiff', 'clue', 'vag_fluid']):
    
    return

def run_roc(roc_meta, meta_amsel, nn, path, save = True, cols = ['nugent_bin', 'ph_bin', 'BV_amsel_bin', 'whiff', 'clue', 'vag_fluid']):
    roc_dict = {}
    
    for col in cols:
        if col in ['nugent_bin', 'ph_bin']:
            df, shuff = all_func(roc_meta, 99, col)
        else:
            df, shuff = all_func(meta_amsel, 99, col)
        roc_dict[col] = df
    if nn:
        path = file_path + 'nn_' + path
    else:
        path = file_path + path
    
    if save:
        paga_res.save_excel(path, roc_dict)
    
    return roc_dict

def all_roc_func(meta, nn, path, save = True, cols = ['nugent_bin', 'ph_bin', 'BV_amsel_bin', 'whiff', 'clue', 'vag_fluid']):
    roc_meta, meta_amsel = order_meta(meta, nn)
#     fig = view_distributions(meta, cols =  ['nugent_bin', 'ph_bin', 'BV_amsel_bin', 'whiff', 'clue', 'vag_fluid'])
    roc_dict = run_roc(roc_meta, meta_amsel, nn, path, save = save, cols = cols)
    
    return roc_dict

# %%
roc_dict = all_roc_func(meta, nn = False, path = 'roc_res_PCA_umap_02072023.xlsx', save = False)
nn_roc_dict = all_roc_func(nn_meta, nn = True, path = 'roc_res_PCA_umap_02072023.xlsx', save = False, cols = ['nugent_bin', 'ph_bin', 'BV_amsel_bin'])

# %% [markdown]
# #### 2. Menstruation delta

# %%
def get_menst(meta, 
              nn,
              path,
              save_cols = ['subjectID', 'CST', 'subCST', 'time', 'day', 'week', 'mt_pseudotime', 'menst', 
                           'ps_diff', 'ps_diff_abs','sum_all'],
             save = True):
    # Filter only to temporal samples
    temp_meta = meta[meta['sampleID'].str.contains('UAB')]
    temp_meta['menst'] = np.where(temp_meta['menst'] >= 1 , 1, 0)
    print('Temporal samples shape: ' + str(temp_meta.shape))
    
    # Pseudotime calculation
    temp_meta['prev_pseudotime'] = temp_meta.groupby('subjectID')['mt_pseudotime'].shift(periods = 1)
    temp_meta['ps_diff'] = temp_meta['mt_pseudotime'] - temp_meta['prev_pseudotime']
    temp_meta['ps_diff_abs'] = temp_meta['ps_diff'].abs()
    
    # Menstruation calculation
    tmp = temp_meta[['time', 'subjectID', 'menst']]
    tmp['prev_menst1'] = tmp.groupby('subjectID')['menst'].shift(periods = -1)
    tmp['prev_menst2'] = tmp.groupby('subjectID')['menst'].shift(periods = -2)
    tmp['next_menst1'] = tmp.groupby('subjectID')['menst'].shift(periods = 1)
    tmp['next_menst2'] = tmp.groupby('subjectID')['menst'].shift(periods = 2)
    tmp['sum_all'] = tmp.loc[:,tmp.columns.str.contains('menst')].sum(axis = 1)
    tmp['sum_all'][tmp['sum_all'] >= 1] = 1
    temp_menst_meta = temp_meta.join(tmp[['sum_all']])
    print('Menstruation samples number: ')
    display(temp_menst_meta.groupby('sum_all')['CST'].count())
    
    if save:
        save_cols = save_cols
        dict_menst = {'meta': temp_menst_meta[save_cols]}
        if nn: 
            menst_path = file_path + 'nn_' + path
        else:
            menst_path = file_path + path
            
        paga_res.save_excel(menst_path, dict_menst)    
    
    return temp_menst_meta

# %%
menst_meta = get_menst(meta, False, 'menst_statistics_res_PCA_umap_02072023.xlsx')
menst_meta = get_menst(nn_meta, True, 'menst_statistics_res_PCA_umap_02072023.xlsx')

# %% [markdown]
# #### 3. Metabolites

# %%
metabolic_path = 'C:/Users/morts/Documents/TAU/Manifold_Project/Data/SPECIFIC_PAPERS/Use_UAB/Borgogna_et_al.2021/'
metabolic_filename = metabolic_path + 'meta_MT.xlsx'
metabolic_meta = pd.read_excel(metabolic_filename, sheet_name = 'meta', index_col = 0)
display(metabolic_meta.shape)

# %%
met_cols = [col for col in metabolic_meta.columns if 'ine' in col]
met_cols.append('total')
metabolic_meta = meta.merge(metabolic_meta[met_cols], left_on = 'sampleID', right_index = True)
metabolic_meta['high_ps'] = np.where(metabolic_meta['mt_pseudotime'] >= 0.9, 1, 0)

# %%
dict_metabolites = {'meta': metabolic_meta[['subjectID', 'mt_pseudotime', 'Cadaverine', 'Putrescine', 'Spermidine', 'Spermine', 'Tyramine', 'total', 'high_ps']]}
metabolic_path = file_path + 'metabolites_with_ps_PCA_umap.xlsx'
paga_res.save_excel(metabolic_path, dict_metabolites)

# %% [markdown]
# #### 4. BV medication

# %%
agg_df = meta.groupby('subjectID')['mt_pseudotime'].aggregate(['std'])
agg_df.hist(column = 'std', figsize = (2.5, 2))
high_std_subjects = agg_df[agg_df['std'] > 0.00001].index
change_index = meta[(meta['subjectID'] == 'UAB003') & (meta['time'] == 56)].index
meta.loc[change_index, 'BV_medication'] = 0.0
# ['BV_medication'] = 1.0

# %%
def flatten_lst(lst):
    return [item for items in lst for item in items]

def select_df_by_indices(df, idx_lsts, predict_group_size, bv_next = 1):
    groups_names = [[i] * (len(x)) for i, x in enumerate(idx_lsts)]
    flatten_idx_lst = flatten_lst(idx_lsts)
    flatten_names_lst = flatten_lst(groups_names)
    
    new_df = df.iloc[flatten_idx_lst]
    new_df['group_name'] = flatten_names_lst
    new_df['bv_next'] = bv_next
    
    return new_df

def ps_after(meta, obj_col, high_std_subjects, predict_group_size = 4):
    # Order by subjectID and time
    temp_meta = meta[(meta['db'] == 'temp_pyro') & meta['subjectID'].isin(high_std_subjects)]
    temp_meta_no = temp_meta.sort_values(['subjectID', 'time'], ascending = [True, False]).reset_index()
    temp_meta_no['cumcount_time'] = temp_meta_no.groupby(['subjectID']).cumcount().add(1)
    
    # Get indices of medication and after
    med_samples_idx = temp_meta_no[(temp_meta_no[obj_col] == 1) & (temp_meta_no['cumcount_time'] > 1)].index
    
    # Filter consecutive indices 
    grouped_after_med_idx = functools.reduce(lambda x,y : x[:-1]+[x[-1]+[y]] if (x[-1][-1]+1==y) else [*x,[y]], med_samples_idx[1:] , [[med_samples_idx[0]]])
#     high_after_med_idx = [min(lst) for lst in grouped_after_med_idx]
    
    # Get after samples and filter df
    after_med_lists = grouped_after_med_idx.copy()
    [lst.extend([lst[0] - 1, lst[-1] + 1]) for lst in after_med_lists]
#     [list(range(num - 2, num + (predict_group_size))) for num in high_after_med_idx if num > predict_group_size - 1]
    after_med_df = select_df_by_indices(temp_meta_no, after_med_lists, predict_group_size = predict_group_size)
    
    return after_med_df, med_samples_idx, grouped_after_med_idx, after_med_lists

# %%
after_med_df, med_samples_idx, grouped_after_med_idx, after_med_lists = ps_after(meta, 'BV_medication', high_std_subjects, predict_group_size = 5)

subjects_num = len(after_med_df.group_name.unique())#len(filt_before_bv_df.group_name.unique())
nrow = 2
ncol = subjects_num // nrow 
fig, axes = plt.subplots(nrow, ncol, figsize = (15, 6), constrained_layout=True)
for group, ax in zip(after_med_df.group_name.unique(), axes.flat):
    plot_df = after_med_df[after_med_df['group_name'] == group].sort_values('time')
    subject = plot_df.subjectID.unique()
    x = plot_df['time']
    y = plot_df['mt_pseudotime']
    c = plot_df['BV_medication']
    ax.set_title(subject)
    ax.scatter(x, y)#, c)
    m, b = np.polyfit(x, y, 1)
    ax.plot(x, m * x + b, color='red')

# %%
med_dict = {'meta': after_med_df}
med_path = file_path + 'after_medication_ps.xlsx'
paga_res.save_excel(med_path, med_dict)

# %% [markdown]
# #### 5. ROC BV from first days ps prediction

# %%
def add_month(meta):
#     temp_meta = meta[meta['db'].isin(['temp_hiseq', 'temp_pyro'])]
    ord_temp_meta = temp_meta.sort_values(['subjectID', 'time'])
    ord_temp_meta = ord_temp_meta.merge(pd.DataFrame(ord_temp_meta.groupby("subjectID")['time'].max()), 
                        left_on = 'subjectID', right_index = True)
    ord_temp_meta.rename(columns = {'time_y':'time_max', 'time_x':'time'}, inplace = True)
    ord_temp_meta['time_max'] = ord_temp_meta['time_max'] // 2
    ord_temp_meta['monthly_time'] = np.where(ord_temp_meta['time'] < (ord_temp_meta['time_max']), '0', '1')
    ord_temp_meta['monthly_subjectID'] = ord_temp_meta['subjectID'].astype(str) + '_' + ord_temp_meta['monthly_time'].astype(str)
    
    return ord_temp_meta

def add_bv_res(ord_temp_meta, group_col, head):
    ord_temp_meta = ord_temp_meta.sort_values([group_col, 'time'])
    head_df = ord_temp_meta.groupby(group_col).head(head)
    head_df = head_df.groupby(group_col).filter(lambda x: (x.BV_bin == 0).all())
    bv_res = ord_temp_meta.groupby(group_col)['BV_bin'].sum().to_frame(name = 'bv_res')
    bv_res[bv_res > 1] = 1
    grouped_head_df = head_df.groupby(group_col)['mt_pseudotime'].aggregate(['min', 'max', 'mean', 'std', 'median'])
    grouped_head_df = grouped_head_df.join(bv_res)
    
    return grouped_head_df

def all_pred_bv_func(df, n, pred_col, label_col):
    filt_df = df[df[label_col].notna()]
    pred_arr = filt_df[pred_col]

    shuffled_df = get_shuffled_df(filt_df, n, label_col)
    final_df = get_roc(shuffled_df, pred_arr)

    return final_df, shuffled_df

# %%
all_meta = pd.concat([meta, nn_meta])
temp_meta = all_meta[all_meta['db'].isin(['temp_pyro'])]

# %%
for head in [3, 4, 5, 6, 7, 8, 9, 10]:
    # mothly
    ord_temp_meta = add_month(all_meta)
    monthly_grouped_head_df = add_bv_res(ord_temp_meta, 'monthly_subjectID', head)
    pred_df_bv, shuff = all_pred_bv_func(monthly_grouped_head_df, 99, 'median', 'bv_res')
#     print('Monthly prediction with ' + str(head) + 'days: ' + str(pred_df_bv.iloc[0, 2]))
    pred_df_bv, shuff = all_pred_bv_func(monthly_grouped_head_df, 99, 'max', 'bv_res')
#     print('Monthly prediction with ' + str(head) + 'days: ' + str(pred_df_bv.iloc[0, 2]))
    pred_df_bv, shuff = all_pred_bv_func(monthly_grouped_head_df, 99, 'mean', 'bv_res')
#     print('Monthly prediction with ' + str(head) + 'days: ' + str(pred_df_bv.iloc[0, 2]))
    
    # all experiment
    grouped_head_df = add_bv_res(all_meta, 'subjectID', head)
    pred_df_bv, shuff = all_pred_bv_func(grouped_head_df, 99, 'median', 'bv_res')
    print('All prediction with ' + str(head) + 'days: ' + str(pred_df_bv.iloc[0, 2]))
    pred_df_bv, shuff = all_pred_bv_func(grouped_head_df, 99, 'mean', 'bv_res')
    print('All prediction with ' + str(head) + 'days: ' + str(pred_df_bv.iloc[0, 2]))
    pred_df_bv, shuff = all_pred_bv_func(grouped_head_df, 99, 'max', 'bv_res')
    print('All prediction with ' + str(head) + 'days: ' + str(pred_df_bv.iloc[0, 2]))
# Out:
# All prediction with 3days: 0.5882352941176471
# All prediction with 3days: 0.5932539682539683
# All prediction with 3days: 0.8004201680672269
# All prediction with 4days: 0.6848739495798319
# All prediction with 4days: 0.6524609843937575
# All prediction with 4days: 0.8377851140456183
# All prediction with 5days: 0.7444614209320092
# All prediction with 5days: 0.6644385026737968
# All prediction with 5days: 0.8389992360580596
# All prediction with 6days: 0.7313550420168068
# All prediction with 6days: 0.6869747899159664
# All prediction with 6days: 0.8424369747899161
# All prediction with 7days: 0.6809723889555822
# All prediction with 7days: 0.629951980792317
# All prediction with 7days: 0.84093637454982
# All prediction with 8days: 0.6743697478991596
# All prediction with 8days: 0.6350540216086434
# All prediction with 8days: 0.8388355342136855
# All prediction with 9days: 0.657563025210084
# All prediction with 9days: 0.6263505402160865
# All prediction with 9days: 0.8340336134453782
# All prediction with 10days: 0.6214985994397759
# All prediction with 10days: 0.569327731092437
# All prediction with 10days: 0.8084733893557422

# %%
head = 7
# ord_temp_meta = add_month(temp_meta)
# grouped_head_df = add_bv_res(ord_temp_meta, 'monthly_subjectID', head)
grouped_head_df = add_bv_res(all_meta, 'subjectID', head)
pred_df_bv, shuff = all_pred_bv_func(grouped_head_df, 99, 'max', 'bv_res')
pred_df_bv.iloc[0, 2]
# Out:
# 0.84093637454982

# %%
curr_df = pred_df_bv[pred_df_bv['shuff_num'] == 'bv_res']
plt.figure(figsize = (3, 2.5))
plt.plot(curr_df['fpr'].values, curr_df['tpr'].values, color="grey", label='', lw=0.5, alpha=0.7)

# %%
bv_pred_dict = {'meta': pred_df_bv}
bv_pred_path = file_path + 'ps_predict_bv_7_max_02072023.xlsx'
paga_res.save_excel(bv_pred_path, bv_pred_dict)

# %% [markdown]
# #### 6. Bacterial abundance in arms

# %%
in_df = pd.read_excel(file_name, sheet_name = sheet_abun, index_col = 0)
display(in_df.shape)
# Out:
# (8026, 373)

# %%
window_size = 0.2
increment = 0.01
n = 12

# %%
abun_df_lst = []
branch_df_lst = []
sumsort_branch_df_lst = []

for branch in meta.CST.unique():
    abun_df, final_window_df, sumsort_window_df = sliding_window.all_window_proc(in_df, 
                                                  meta, branch, 'subCST', 'IV-C0',  window_size, increment, n)
    abun_df_lst.append(abun_df)
    branch_df_lst.append(final_window_df)
    sumsort_branch_df_lst.append(sumsort_window_df)

# %%
sum_spec_lst = ['Bifidobacterium', 'Prevotella', 'Staphylococcus', 'Sneathia','Atopobium', 'Mobiluncus', 
            'Finegoldia', 'Corynebacterium', 'Aerococcus', 'Streptococcus']

# %%
sum_branch_df_lst = []
for i, branch in enumerate(meta.CST.unique()):
    df = sumsort_branch_df_lst[i].copy()
    for spec in sum_spec_lst:
        sum_cols = [col for col in df.columns if spec in col]
        sum_col_name = spec + '_' + branch
        if len(sum_cols) > 1:
            df[sum_col_name] = df[sum_cols].sum(axis = 1)
            df.drop(sum_cols, axis = 1, inplace = True)
        elif len(sum_cols) == 1:
            df = df.rename(columns = {sum_cols[0]: sum_col_name})
    sum_branch_df_lst.append(df)

# %%
ord_df = sliding_window.get_order(sum_branch_df_lst)
melt_df = sliding_window.get_melt(ord_df)
melt_df['species'] = melt_df['species'].replace({'o_': '', 'g_': ''})

# %%
dict_melt = {'melt_branch_df': melt_df}
melt_path = file_path + 'branch_melt_df_PCA_umap_02072023.xlsx'
paga_res.save_excel(melt_path, dict_melt)

# %%
fig = px.scatter(melt_df, x = 'mt_pseudotime', y = 'value', color = 'species', 
           facet_col = 'branch', facet_col_wrap = 3)
fig.update_layout(autosize = False, width = 1000, height = 600)
fig.update_yaxes(matches = None)
fig.show()
# Out:
# <div>                            <div id="faf72a09-ed93-43dd-8e07-28088a4448f2" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("faf72a09-ed93-43dd-8e07-28088a4448f2")) {                    Plotly.newPlot(                        "faf72a09-ed93-43dd-8e07-28088a4448f2",                        [{"hovertemplate":"species=Lactobacillus_crispatus<br>branch=I<br>mt_pseudotime=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Lactobacillus_crispatus","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Lactobacillus_crispatus","showlegend":true,"x":[0.11694266931656151,0.12205227449828503,0.12709200733788212,0.13365562228780042,0.1433323561543166,0.15247585254659862,0.1637557394447781,0.17086441679434342,0.1809228426246552,0.18895014979298275,0.19620370316268199,0.2045805592145493,0.2127191783506659,0.22173805515686468,0.23244022390254296,0.24265465610053227,0.25480547032944145,0.26460747124434186,0.2728790182201594,0.28320253857274563,0.29268903951895864,0.30232358415805,0.31318767917783635,0.32131253579664515,0.3421957152947951,0.357909074006987,0.3736346314625187,0.38266483532345813,0.39406962822312896,0.40019976030638876,0.40765741132797406,0.41557489937236963,0.42575758227503113,0.434896750967632,0.44174775613505907,0.4501152235192138,0.4606191181327282,0.47156362587483086,0.48113603314621556,0.48792431742171494,0.4944627489529404,0.5013073079361774,0.5094231788377116,0.5178446609015558,0.5309855786149688,0.5423276644538749,0.5556861853808077,0.5663023081149323,0.5789748202351963,0.5904129597570436,0.5976643817273178,0.6028498451499378,0.6146728676266786,0.6227407239732288,0.6316793908211301,0.6441245308709801,0.6553704096861412,0.6687361921911454,0.687414445869409,0.6977711433630723,0.7079526008786382,0.7172226682086844,0.7272661710265039,0.7414575105621701,0.7507519052431347,0.7592879133298993,0.7680881309635091,0.7746238819351093,0.7824588308871632,0.7919220033793422,0.7971399293414184,0.800724607670591,0.8047813996441963,0.8065577611515794,0.8130745920978608,0.8190874596366613,0.8239227710361767,0.8303963807664176,0.8379576778930167,0.8469116086051578,0.8526770914042437],"xaxis":"x7","y":[99.55586766628447,99.5181785013369,99.48453641612831,99.4457254183505,99.38693665344493,99.33553906840277,99.26619700779175,99.21711976244396,99.13637483577592,99.08553664308361,99.0268730400281,98.95821604133982,98.88502279898483,98.78965206240133,98.67600036531798,98.55423323042933,98.40715247488315,98.28990710620768,98.17322895267627,98.0352601227936,97.91154229609333,97.75951184614303,97.58320817775402,97.45208531664606,97.33778302906072,96.9956944287395,96.66266519774793,96.43909474876061,96.18574232200682,96.01063130255791,95.79091205168405,95.5609967145595,95.21226022071713,94.93641528769997,94.71907243937432,94.5183379178333,94.22935773950367,94.13992310881183,94.00134028235173,93.7232071403008,93.39340819089996,93.0689750529544,92.65169807058072,92.14721818427796,91.29354185683157,90.70789463855164,89.88260806163423,89.18600915817,88.19268629283854,87.31362608553273,86.67221403559321,86.27327079314814,85.36754484156755,84.7100817606624,83.91384075247947,82.54739517505818,81.32915840019156,79.52224589574996,76.85003870037437,75.30438875654998,73.88471723317403,72.51392034489056,71.17686514417518,69.10517295104621,67.46590245879206,65.94208898150849,64.46617036231302,63.39317613528132,62.230116697117886,60.70373496076052,59.910582605153735,58.854162337386796,58.08782381492986,57.74642709800017,56.375102340037635,55.1302590939198,53.99187495294509,52.266898505696275,50.58588028698513,48.69311476089639,47.481705637927405],"yaxis":"y7","type":"scattergl"},{"hovertemplate":"species=Lactobacillus_crispatus<br>branch=IV-C<br>mt_pseudotime=%{x}<br>value=%{y}<extra></extra>","legendgroup" ...

# %%
grouped_spec_df = melt_df.loc[melt_df.groupby(['species', 'branch'])['mt_pseudotime'].idxmax()].reset_index(drop=True)
for spec in grouped_spec_df.species.unique():
    display(grouped_spec_df[grouped_spec_df['species'] == spec])
# Out:
#    mt_pseudotime     value     species branch
# 0       0.903329  1.023924  Aerococcus    III
#    mt_pseudotime      value    species branch
# 1       0.903329   1.722224  Atopobium    III
# 2       0.931779   2.720123  Atopobium   IV-A
# 3       0.975948  11.606802  Atopobium   IV-B
#    mt_pseudotime      value species branch
# 4       0.931779  37.678939   BVAB1   IV-A
#    mt_pseudotime      value          species branch
# 5       0.878535   2.914763  Bifidobacterium     II
# 6       0.930985  14.404958  Bifidobacterium   IV-C
# 7       0.880174   0.633962  Bifidobacterium      V
#     mt_pseudotime     value          species branch
# 8        0.852677  0.948599  Corynebacterium      I
# 9        0.878535  2.180855  Corynebacterium     II
# 10       0.930985  2.462933  Corynebacterium   IV-C
# 11       0.880174  0.935976  Corynebacterium      V
#     mt_pseudotime     value     species branch
# 12       0.852677  1.187691  Finegoldia      I
# 13       0.878535  1.996439  Finegoldia     II
# 14       0.903329  0.643158  Finegoldia    III
# 15       0.880174  0.815315  Finegoldia      V
#     mt_pseudotime      value                species branch
# 16       0.852677   9.273553  Gardnerella_vaginalis      I
# 17       0.878535   2.809080  Gardnerella_vaginalis     II
# 18       0.903329  11.375882  Gardnerella_vaginalis    III
# 19       0.931779  14.090642  Gardnerella_vaginalis   IV-A
# 20       0.975948  45.709262  Gardnerella_vaginalis   IV-B
# 21       0.930985   2.161708  Gardnerella_vaginalis   IV-C
# 22       0.880174   7.722860  Gardnerella_vaginalis      V
#     mt_pseudotime     value                  species branch
# 23       0.852677  2.767380  Lactobacillus_Cluster_1      I
# 24       0.878535  6.733157  Lactobacillus_Cluster_1     II
# 25       0.903329  0.788965  Lactobacillus_Cluster_1    III
# 26       0.975948  0.948158  Lactobacillus_Cluster_1   IV-B
# 27       0.930985  2.986216  Lactobacillus_Cluster_1   IV-C
# 28       0.880174  0.744625  Lactobacillus_Cluster_1      V
#     mt_pseudotime      value                  species branch
# 29       0.852677  47.481706  Lactobacillus_crispatus      I
# 30       0.878535   2.428743  Lactobacillus_crispatus     II
# 31       0.903329   6.341399  Lactobacillus_crispatus    III
# 32       0.975948   0.990091  Lactobacillus_crispatus   IV-B
# 33       0.930985   2.069150  Lactobacillus_crispatus   IV-C
# 34       0.880174   6.916134  Lactobacillus_crispatus      V
#     mt_pseudotime     value                    species branch
# 35       0.975948  0.137231  Lactobacillus_delbrueckii   IV-B
#     mt_pseudotime      value                species branch
# 36       0.852677   4.068635  Lactobacillus_gasseri      I
# 37       0.878535  57.738151  Lactobacillus_gasseri     II
# 38       0.903329   0.545171  Lactobacillus_gasseri    III
# 39       0.930985   1.413680  Lactobacillus_gasseri   IV-C
# 40       0.880174   3.919357  Lactobacillus_gasseri      V
#     mt_pseudotime      value              species branch
# 41       0.852677  11.420651  Lactobacillus_iners      I
# 42       0.878535   1.415047  Lactobacillus_iners     II
# 43       0.903329  56.607788  Lactobacillus_iners    III
# 44       0.931779   4.737636  Lactobacillus_iners   IV-A
# 45       0.975948   6.304570  Lactobacillus_iners   IV-B
# 46       0.930985   2.394971  Lactobacillus_iners   IV-C
# 47       0.880174  17.671912  Lactobacillus_iners      V
#     mt_pseudotime      value                 species branch
# 48       0.852677   6.506507  Lactobacillus_jensenii      I
# 49       0.878535   1.256917  Lactobacillus_jensenii     II
# 50       0.903329   3.251072  Lactobacillus_jensenii    III
# 51       0.975948   0.310584  Lactobacillus_jensenii   IV-B
# 52       0.880174  52.295432  Lactobacillus_jensenii      V
#     mt_pseudotime     value                 species branch
# 53       0.880174  0.372666  Lactobacillus_psittaci      V
#     mt_pseudotime     value     species branch
# 54       0.931779  1.386731  Mobiluncus   IV-A
#     mt_pseudotime      value species branch
# 55       0.852677  12.113529  Others      I
# 56       0.878535  13.390588  Others     II
# 57       0.903329  14.539802  Others    III
# 58       0.931779  21.017309  Others   IV-A
# 59       0.975948  22.512672  Others   IV-B
# 60       0.930985  21.623451  Others   IV-C
# 61       0.880174   6.476621  Others      V
#     mt_pseudotime     value     species branch
# 62       0.878535  2.251290  Prevotella     II
# 63       0.931779  5.813771  Prevotella   IV-A
# 64       0.975948  1.580253  Prevotella   IV-B
# 65       0.930985  2.640611  Prevotella   IV-C
#     mt_pseudotime     value   species branch
# 66       0.931779  4.403437  Sneathia   IV-A
# 67       0.975948  4.271696  Sneathia   IV-B
#     mt_pseudotime     value         species branch
# 68       0.930985  7.863103  Staphylococcus   IV-C
#     mt_pseudotime      value        species branch
# 69       0.852677   1.332940  Streptococcus      I
# 70       0.878535   2.028280  Streptococcus     II
# 71       0.903329   0.953223  Streptococcus    III
# 72       0.930985  30.932891  Streptococcus   IV-C
# 73       0.880174   0.907396  Streptococcus      V
#     mt_pseudotime     value         species branch
# 74       0.852677  0.978431  g_Anaerococcus      I
# 75       0.878535  2.851091  g_Anaerococcus     II
#     mt_pseudotime    value         species branch
# 76       0.930985  6.47643  g_Enterococcus   IV-C
#     mt_pseudotime    value           species branch
# 77       0.975948  2.22227  g_Mageeibacillus   IV-B
#     mt_pseudotime     value        species branch
# 78       0.903329  1.934170  g_Megasphaera    III
# 79       0.931779  5.271629  g_Megasphaera   IV-A
# 80       0.975948  3.406016  g_Megasphaera   IV-B
#     mt_pseudotime     value       species branch
# 81       0.931779  1.242563  g_Parvimonas   IV-A
#     mt_pseudotime     value          species branch
# 82       0.852677  0.890701  g_Peptoniphilus      I
# 83       0.880174  0.587043  g_Peptoniphilus      V
#     mt_pseudotime     value        species branch
# 84       0.852677  1.026597  g_Pseudomonas      I
# 85       0.930985  2.569801  g_Pseudomonas   IV-C
#     mt_pseudotime     value       species branch
# 86       0.903329  0.272588  g_Ureaplasma    III
#     mt_pseudotime     value              species branch
# 87       0.931779  1.636473  o_Saccharimonadales   IV-A
