# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.decomposition import PCA
from sklearn.manifold import MDS
from sklearn.manifold import TSNE
from sklearn.linear_model import LinearRegression
from skbio.diversity import beta_diversity, alpha_diversity
from skbio.stats.ordination import pcoa, pcoa_biplot
from skbio import DistanceMatrix
from scipy.stats import spearmanr, pearsonr
import statsmodels.api as sm 
import umap
from io import StringIO
from os.path import join
import pandas as pd
import xlsxwriter
import openpyxl
import os
import numpy as np
import itertools
import itertools as it
import kaleido
from pandas import Series, ExcelWriter
import scipy.io as sio
import plotly.graph_objects as go
import plotly.io as pio
import plotly.express as px
import seaborn as sns
from IPython.display import display, HTML
from fpdf import FPDF
import scanpy as sc 
from anndata import AnnData
import csv
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.lines import Line2D  # for legend handle

# %% [markdown]
# #### Variables

# %%
place = "home"

# %%
if place == "lab":
    ps_file_path = "D:/user/OneDrive/Mor_TAU/BV_project/Data/abundance_tables/"
elif place == "home":
    ps_file_path = "C:/Users/morts/Documents/TAU/BV_Project/Data/Pseudo_time_analysis/Ravel11/PCA_16082021/"

ps_file_name = "pseudo_time_Ravel11_MT_16082021_PCA"
ps_sheet_name_data = 'abundance_pseudo'
ps_sheet_name_meta = 'metadata_pseudo'
ps_sheet_name_plot = 'graphs_values_pseudo'
ps_sheet_name_params = 'params'

if place == "lab":
    all_file_path = "D:/user/OneDrive/Mor_TAU/BV_project/Data/abundance_tables/"
elif place == "home":
    all_file_path = "C:/Users/morts/Documents/TAU/BV_Project/Data/abundance_tables/"

file_name = "abundance_table_Gajer2012"
sheet_name_data = 'for_PCA1'
sheet_name_meta = 'for_PCA_metadata'

## knn path
knn_file_name = 'temp_over_ps_knn_opt29082021'
sheet_knn_euc = "euc_knn_res_df"
sheet_knn_bc = "bc_knn_res_df"
sheet_both_pcoa = "both_pca_df"

# %% [markdown]
# #### Load data

# %%
def get_data(all_file_path, file_name, sheet_name):
    file_full_name = all_file_path + file_name + '.xlsx'        
    df = pd.read_excel(file_full_name, sheet_name = sheet_name, index_col = 0)
    
    if "subjectID" in df.columns:
        df["subjectID"] = df["subjectID"].astype(object)
        
    return df

# %%
## Pseudotime DF
ps_df = get_data(ps_file_path, ps_file_name, ps_sheet_name_data)

ps_meta_df = get_data(ps_file_path, ps_file_name, ps_sheet_name_meta)
ps_meta_df = ps_meta_df.loc[:, ~ ps_meta_df.columns.str.startswith('branch_')]

ps_fa_df = get_data(ps_file_path, ps_file_name, ps_sheet_name_plot)
ps_fa_df = ps_fa_df[['fa1', 'fa2', 'mt_pseudotime']]

## Temp DF
temp_df = get_data(all_file_path, file_name, sheet_name_data)

temp_meta_df = get_data(all_file_path, file_name, sheet_name_meta)
temp_meta_df['DB_type'] = 'temp'
temp_meta_df['subjectID'] = 'subID_' + temp_meta_df['subjectID'].astype(str)

## knn DFs
euc_knn_df = get_data(ps_file_path, knn_file_name, sheet_knn_euc)
bc_knn_df = get_data(ps_file_path, knn_file_name, sheet_knn_bc)
both_pca_df = get_data(ps_file_path, knn_file_name, sheet_both_pcoa)
# Out:
# C:\Users\morts\miniconda3\envs\py37\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# #### Add nearest neighbor mt_pseudotime

# %%
ps_meta_df
# Out:
#           leiden_anno  dpt_pseudotime  mt_branch_I/IV  mt_branch_II/IV  \
# sampleID
# S001                0        0.568507        0.431493              NaN
# S002                6        0.481564             NaN         0.518436
# S003               10        0.435093             NaN              NaN
# S004                3        0.818600        0.181400              NaN
# S005                2        0.000000        1.000000         1.000000
# ...               ...             ...             ...              ...
# S390                7        0.319088             NaN              NaN
# S391               10        0.446637             NaN              NaN
# S392                5        0.140578        0.859422         0.859422
# S393                9        0.932655             NaN              NaN
# S394                1        0.531380             NaN              NaN
#
#           mt_branch_III/IV  mt_branch_V/IV  mt_branch_III/V  mt_branch_I/III  \
# sampleID
# S001                   NaN             NaN              NaN         0.431493
# S002                   NaN             NaN              NaN              NaN
# S003                   NaN             NaN         0.564907              NaN
# S004                   NaN             NaN              NaN         0.181400
# S005              1.000000        1.000000              NaN              NaN
# ...                    ...             ...              ...              ...
# S390              0.680912             NaN              NaN              NaN
# S391                   NaN             NaN         0.553363              NaN
# S392              0.859422        0.859422              NaN              NaN
# S393              0.067345             NaN         0.067345         0.067345
# S394              0.468620             NaN         0.468620         0.468620
#
#           mt_branch_IV/IV  mt_pseudotime ethnicity   ph  nugent  nugent_score  \
# sampleID
# S001                  NaN       0.431493     Asian  4.0       0           low
# S002                  NaN       0.518436     White  4.0       0           low
# S003                  NaN       0.564907     Black  4.0       1           low
# S004                  NaN       0.181400     Asian  4.7       0           low
# S005                  1.0       1.000000     Black  5.0       6  intermediate
# ...                   ...            ...       ...  ...     ...           ...
# S390                  NaN       0.680912     Asian  7.0       6  intermediate
# S391                  NaN       0.553363     Asian  4.4       0           low
# S392                  NaN       0.859422     Asian  4.4       0           low
# S393                  NaN       0.067345     Asian  4.4       0           low
# S394                  NaN       0.468620     Asian  4.4       2           low
#
#          community DB_type
# sampleID
# S001             I    cros
# S002            II    cros
# S003           III    cros
# S004             I    cros
# S005            IV    cros
# ...            ...     ...
# S390           III    cros
# S391           III    cros
# S392            IV    cros
# S393           III    cros
# S394           III    cros
#
# [394 rows x 16 columns]

# %%
def get_pseudotime(knn_df, meta_df, temp_meta_df):
    branch_cols = [col for col in meta_df.columns if col.startswith('mt_')]
    branch_cols.append('leiden_anno')
    res_df = pd.merge(knn_df, meta_df[branch_cols], left_on = 'closest_sample', right_index = True)
    final_res_df = pd.merge(res_df, temp_meta_df, right_index = True, left_index = True)
    
    return final_res_df

# %%
bc_ps_df = get_pseudotime(bc_knn_df, ps_meta_df, temp_meta_df)
euc_ps_df = get_pseudotime(euc_knn_df, ps_meta_df, temp_meta_df)
display(bc_ps_df)
# Out:
#            closest_sample  distance  mt_branch_I/IV  mt_branch_II/IV  \
# sampleID
# 400_010106           S228  0.219586             NaN              NaN
# 415_100606           S228  0.326314             NaN              NaN
# 400_010506           S223  0.052010             NaN              NaN
# 400_012606           S223  0.024568             NaN              NaN
# 406_051306           S223  0.062591             NaN              NaN
# ...                   ...       ...             ...              ...
# 443_040207           S294  0.014878        0.216142              NaN
# 444_020107           S370  0.561204        0.863529         0.863529
# 444_022407           S177  0.234566        0.973298         0.973298
# 445_012207           S316  0.468276        0.911640              NaN
# 446_032307           S157  0.024513             NaN              NaN
#
#             mt_branch_III/IV  mt_branch_V/IV  mt_branch_III/V  \
# sampleID
# 400_010106          0.684365             NaN              NaN
# 415_100606          0.684365             NaN              NaN
# 400_010506          0.526034             NaN         0.526034
# 400_012606          0.526034             NaN         0.526034
# 406_051306          0.526034             NaN         0.526034
# ...                      ...             ...              ...
# 443_040207               NaN             NaN              NaN
# 444_020107          0.863529        0.863529              NaN
# 444_022407          0.973298        0.973298              NaN
# 445_012207          0.911640             NaN              NaN
# 446_032307               NaN             NaN         0.570321
#
#             mt_branch_I/III  mt_branch_IV/IV  mt_pseudotime  leiden_anno  \
# sampleID
# 400_010106              NaN              NaN       0.684365            7
# 415_100606              NaN              NaN       0.684365            7
# 400_010506         0.526034              NaN       0.526034            1
# 400_012606         0.526034              NaN       0.526034            1
# 406_051306         0.526034              NaN       0.526034            1
# ...                     ...              ...            ...          ...
# 443_040207         0.216142              NaN       0.216142            3
# 444_020107              NaN              NaN       0.863529            5
# 444_022407              NaN         0.973298       0.973298            2
# 445_012207              NaN              NaN       0.911640            4
# 446_032307              NaN              NaN       0.570321           10
#
#             time subjectID ethnicity  age  nugent nugent_score community  \
# sampleID
# 400_010106     1  subID_20     Black   45     NaN          NaN      IV-A
# 415_100606   107  subID_21  Hispanic   23     0.0          Low      IV-A
# 400_010506     5  subID_20     Black   45     0.0          Low       III
# 400_012606    26  subID_20     Black   45     0.0          Low       III
# 406_051306    99  subID_11     Black   39     1.0          Low       III
# ...          ...       ...       ...  ...     ...          ...       ...
# 443_040207    91  subID_32     Black   42     0.0          Low         I
# 444_020107    29   subID_7     Black   43     0.0          Low      IV-B
# 444_022407    52   subID_7     Black   43     NaN          NaN      IV-B
# 445_012207    12   subID_2     Black   37     0.0          Low      IV-A
# 446_032307    22  subID_16     White   33     0.0          Low       III
#
#            DB_type
# sampleID
# 400_010106    temp
# 415_100606    temp
# 400_010506    temp
# 400_012606    temp
# 406_051306    temp
# ...            ...
# 443_040207    temp
# 444_020107    temp
# 444_022407    temp
# 445_012207    temp
# 446_032307    temp
#
# [937 rows x 19 columns]

# %% [markdown]
# #### Change branches to unique for chr plots

# %%
def get_partial_pseudotime(df, leiden_lst, column_name):
    full_column_name = 'mt_branch_' + column_name
    df[full_column_name] = [df.loc[index, 'mt_pseudotime'] if df.loc[index, 'leiden_anno'] in leiden_lst
                           else np.nan
                           for index in df.index]

    return df

# %%
def get_unique(df):
    new_df = df[['leiden_anno', 'mt_pseudotime', 'time', 'subjectID', 'nugent', 'community']]
    
    ## Branch columns
    new_df = get_partial_pseudotime(new_df, [3, 0], 'I/IV') 
    new_df = get_partial_pseudotime(new_df, [6], 'II/IV')
    new_df = get_partial_pseudotime(new_df, [9, 8, 1, 7], 'III/IV')
    new_df = get_partial_pseudotime(new_df, [12], 'V/IV')
    new_df = get_partial_pseudotime(new_df, [10], 'III/V')
    new_df = get_partial_pseudotime(new_df, [11, 13], 'I/III')
    new_df = get_partial_pseudotime(new_df, [4, 5, 2, 14], 'IV')

    return new_df

# %%
bc_ps_unique_df = get_unique(bc_ps_df)
print(bc_ps_unique_df.info())

display(bc_ps_unique_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 937 entries, 400_010106 to 446_032307
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   leiden_anno       937 non-null    int64
#  1   mt_pseudotime     937 non-null    float64
#  2   time              937 non-null    int64
#  3   subjectID         937 non-null    object
#  4   nugent            889 non-null    float64
#  5   community         937 non-null    object
#  6   mt_branch_I/IV    165 non-null    float64
#  7   mt_branch_II/IV   56 non-null     float64
#  8   mt_branch_III/IV  301 non-null    float64
#  9   mt_branch_V/IV    0 non-null      float64
#  10  mt_branch_III/V   33 non-null     float64
#  11  mt_branch_I/III   46 non-null     float64
#  12  mt_branch_IV      336 non-null    float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 134.8+ KB
# None
# C:\Users\morts\miniconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#             leiden_anno  mt_pseudotime  time subjectID  nugent community  \
# sampleID
# 400_010106            7       0.684365     1  subID_20     NaN      IV-A
# 415_100606            7       0.684365   107  subID_21     0.0      IV-A
# 400_010506            1       0.526034     5  subID_20     0.0       III
# 400_012606            1       0.526034    26  subID_20     0.0       III
# 406_051306            1       0.526034    99  subID_11     1.0       III
# ...                 ...            ...   ...       ...     ...       ...
# 443_040207            3       0.216142    91  subID_32     0.0         I
# 444_020107            5       0.863529    29   subID_7     0.0      IV-B
# 444_022407            2       0.973298    52   subID_7     NaN      IV-B
# 445_012207            4       0.911640    12   subID_2     0.0      IV-A
# 446_032307           10       0.570321    22  subID_16     0.0       III
#
#             mt_branch_I/IV  mt_branch_II/IV  mt_branch_III/IV  mt_branch_V/IV  \
# sampleID
# 400_010106             NaN              NaN          0.684365             NaN
# 415_100606             NaN              NaN          0.684365             NaN
# 400_010506             NaN              NaN          0.526034             NaN
# 400_012606             NaN              NaN          0.526034             NaN
# 406_051306             NaN              NaN          0.526034             NaN
# ...                    ...              ...               ...             ...
# 443_040207        0.216142              NaN               NaN             NaN
# 444_020107             NaN              NaN               NaN             NaN
# 444_022407             NaN              NaN               NaN             NaN
# 445_012207             NaN              NaN               NaN             NaN
# 446_032307             NaN              NaN               NaN             NaN
#
#             mt_branch_III/V  mt_branch_I/III  mt_branch_IV
# sampleID
# 400_010106              NaN              NaN           NaN
# 415_100606              NaN              NaN           NaN
# 400_010506              NaN              NaN           NaN
# 400_012606              NaN              NaN           NaN
# 406_051306              NaN              NaN           NaN
# ...                     ...              ...           ...
# 443_040207              NaN              NaN           NaN
# 444_020107              NaN              NaN      0.863529
# 444_022407              NaN              NaN      0.973298
# 445_012207              NaN              NaN      0.911640
# 446_032307         0.570321              NaN           NaN
#
# [937 rows x 13 columns]

# %%
euc_ps_unique_df = get_unique(euc_ps_df)
print(euc_ps_unique_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 937 entries, 400_010106 to 446_032307
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   leiden_anno       937 non-null    int64
#  1   mt_pseudotime     937 non-null    float64
#  2   time              937 non-null    int64
#  3   subjectID         937 non-null    object
#  4   nugent            889 non-null    float64
#  5   community         937 non-null    object
#  6   mt_branch_I/IV    175 non-null    float64
#  7   mt_branch_II/IV   55 non-null     float64
#  8   mt_branch_III/IV  276 non-null    float64
#  9   mt_branch_V/IV    0 non-null      float64
#  10  mt_branch_III/V   48 non-null     float64
#  11  mt_branch_I/III   50 non-null     float64
#  12  mt_branch_IV      333 non-null    float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 134.8+ KB
# None
# C:\Users\morts\miniconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# #### Plot with shape as branch

# %%
def get_ps_to_ch_shape(df):
    grouped = df.groupby('subjectID')
    rowlength = int(grouped.ngroups/4)
    branch_cols = [col for col in df.columns if col.startswith('mt_branch_')]
    markers_lst = ['o', '^', 's', 'D', '*', 'P', 'X']
    
    branch_markers = dict(zip(branch_cols, markers_lst))
    
    community_colors = {'I':'darkred', 'II':'orange', 'III':'chocolate', 'V':'yellow', 
              'IV':'mediumturquoise', 'IV-A':'mediumpurple', 'IV-B':'royalblue'}
    
    fig, axs = plt.subplots(figsize = (9, 15), nrows = rowlength, ncols = 4, sharey = True, sharex = True) 
    
    targets = zip(grouped.groups.keys(), axs.flatten())
    
    for i, (key, ax) in enumerate(targets):       
        temp_df = grouped.get_group(key)
        sort_df = temp_df.sort_values('time')
        ax.plot(sort_df['time'], sort_df['mt_pseudotime'], color = 'black', zorder = -1, linewidth = 0.7)
        for col, shape in branch_markers.items():
            col_temp_df = temp_df[['time', 'community', col]].dropna()
            ax.scatter(x = col_temp_df['time'], y = col_temp_df[col],
              c = col_temp_df.loc[:, 'community'].map(community_colors), 
              alpha = 0.6, s = 90, edgecolor = 'black', marker = shape)

        ax.text(0.07, 0.1, key.replace('subID_', ''), ha = 'center', va = 'center', transform = ax.transAxes)
        ax.legend().remove()
        ax.tick_params(axis = 'both', which = 'major', labelsize = 12)
    
    handles_community = [Line2D([0], [0], marker = 'o', color = 'w', markerfacecolor = v, label = k, markersize = 15) 
               for k, v in community_colors.items()]
    handles_branch = [Line2D([0], [0], marker = v, color = 'black', linestyle = 'None', label = k.replace('mt_branch_', ''), 
               markersize = 11.5) 
               for k, v in branch_markers.items()]
    fig.legend(title = 'Community \n state type', handles = handles_community, bbox_to_anchor = (0.79, 0.85), 
               loc = 'upper left', fontsize = 13, title_fontsize = 15)
    fig.legend(title = 'Branch', handles = handles_branch, bbox_to_anchor = (0.79, 0.6), 
               loc = 'upper left', fontsize = 13, title_fontsize = 15)
    
    fig.text(0.5, 0.02, 'Chronological time (days)', ha = 'center', size = 18)
    fig.text(0.03, 0.45, 'Pseudotimetime', va = 'center', rotation = 'vertical', size = 18)
    
    fig.subplots_adjust(left = 0.125, right = 0.79, bottom = 0.05, top = 0.9, wspace = 0.08, hspace = 0.08)

    return fig

# %%
bc_fig_shape = get_ps_to_ch_shape(bc_ps_unique_df)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
euc_fig_shape = get_ps_to_ch_shape(euc_ps_unique_df)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
bc_shape_path = ps_file_path + 'Gajer2012_knn_figures/' + 'bc_ps_by_branch.png'
bc_fig_shape.savefig(bc_shape_path, dpi = 500)

euc_shape_path = ps_file_path + 'Gajer2012_knn_figures/' + 'euc_ps_by_branch.png'
euc_fig_shape.savefig(euc_shape_path, dpi = 500)

# %% [markdown]
# #### Shannon diversity index to pseudotime

# %%
def get_shannon(df):
    shannon_vec = alpha_diversity(counts = df.values, metric = 'shannon')
    shannon_df = pd.DataFrame(shannon_vec, columns = ['shannon_index'])
    shannon_df = shannon_df.set_index(df.index)
    
    return shannon_df

# %%
def get_reg(x, y):
    z = np.polyfit(x, y, 1)
    p = np.poly1d(z)
   
    correlation = np.corrcoef(x, y)[0,1]
    SSreg = correlation**2
    
    return p, round(SSreg, 4)

# %%
def get_pseudo_vs_time_plots(df, y_col_name, ps_x_col_name, ch_x_col_name):
    ## Variables
    figsize_x = 8
    figsize_y = 25
    ax_size = 15
    lab_size = 18
    point_size = 130
    leg_size = 12
    
    ## DF variables
    df.replace([np.inf, -np.inf], np.nan, inplace = True)
    branch_col_lst = [col for col in df.columns if 'mt_branch_' in col and 'IV' in col and 'IV/IV' not in col]
    nrow_subplots = len(branch_col_lst)
    
    ##
    figure, axs = plt.subplots(nrow_subplots, 1, sharey = True, figsize = (figsize_x, figsize_y))
    community_colors = {'I':'crimson', 'II':'orange', 'III':'chocolate', 'V':'gold', 
              'IV':'steelblue', 'IV-A':'aqua', 'IV-B':'springgreen'}
    
    ## Plots
    for i in range(0, nrow_subplots):
        # Order x, y arrays
        curr_df = df[df[branch_col_lst[i]].notna()]
        curr_df = curr_df[curr_df[y_col_name].notna()]
        curr_df = curr_df[~ curr_df['community'].isin(['IV-A', 'IV-B'])]
        
        ps_y_label_name = y_col_name.replace('_', ' ') + ' ' + branch_col_lst[i].replace('mt_branch_', '')
        ps_x = np.array(curr_df.loc[:, branch_col_lst[i]])
        y = np.array(curr_df.loc[:, y_col_name])
        
        ######### Pseudotime plot
        ax1 = axs[i]
        ps_sc = ax1.scatter(ps_x, y,
                   c = curr_df['community'].map(community_colors),
                   s = point_size, edgecolor = 'black', alpha = 0.6)
        ax1.set_ylabel(ps_y_label_name, size = lab_size)
        ax1.tick_params(axis = 'both', which = 'major', labelsize = ax_size)
        
        if i == nrow_subplots - 1:
            ax1.set_xlabel('Pseudotime', size = lab_size)
        if i == 0:
            handles = [Line2D([0], [0], marker = 'o', color = 'w', markerfacecolor = v, label = k, markersize = leg_size) 
            for k, v in community_colors.items()]
            ax1.legend(title = 'Community state type', handles = handles, loc = 'upper left')
        
        # Add reggression line and R squared
        ps_p, ps_r = get_reg(ps_x, y)
        ax1.plot(ps_x, ps_p(ps_x), "r-o", c = 'black', linewidth = 0.8, markersize = 2) 
        
        ps_r_squared = 'R^2 = ' + str(ps_r)
        ax1.annotate(ps_r_squared, xy = (1, 0), xycoords = 'axes fraction', fontsize = lab_size,
                xytext = (-5, 5), textcoords = 'offset points',
                ha = 'right', va = 'bottom')
    
    return figure

# %%
shannon_df = get_shannon(temp_df)
bc_meta_df = bc_ps_df.merge(shannon_df, left_index = True, right_index = True)
euc_meta_df = euc_ps_df.merge(shannon_df, left_index = True, right_index = True)

# %%
bc_shannon_fig = get_pseudo_vs_time_plots(bc_meta_df, 'shannon_index', 'mt_pseudotime', 'time')
bc_path = ps_file_path + 'Shannon_Figures_16082021/' + 'shannon_fig_matplotlib_bc_knn_30082021.png'
bc_shannon_fig.savefig(bc_path, dpi = 500)
# Out:
# C:\Users\morts\miniconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:47: RankWarning: Polyfit may be poorly conditioned
# C:\Users\morts\miniconda3\envs\py37\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\morts\miniconda3\envs\py37\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\morts\miniconda3\envs\py37\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)

# %%
euc_shannon_fig = get_pseudo_vs_time_plots(euc_meta_df, 'shannon_index', 'mt_pseudotime', 'time')
euc_path = ps_file_path + 'Shannon_Figures_16082021/' + 'shannon_fig_matplotlib_euc_knn_30082021.png'
euc_shannon_fig.savefig(euc_path, dpi = 500)
# Out:
# C:\Users\morts\miniconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:47: RankWarning: Polyfit may be poorly conditioned
# C:\Users\morts\miniconda3\envs\py37\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\morts\miniconda3\envs\py37\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# C:\Users\morts\miniconda3\envs\py37\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
